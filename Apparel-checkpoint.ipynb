# %%
#import all the necessary packages.

from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import math
import time
import re
import os
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity  
from sklearn.metrics import pairwise_distances
from matplotlib import gridspec
from scipy.sparse import hstack
import plotly
import plotly.figure_factory as ff
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_json('tops_fashion.json')
data
# Out:
#               asin author                         availability  \
# 0       B016I2TS4W   None                                 None
# 1       B01N49AI08   None                                 None
# 2       B01JDPCOHO   None                                 None
# 3       B01N19U5H5   None                                 None
# 4       B004GSI2OS   None  Usually ships in 6-10 business days
# 5       B00TAEHGGS   None                                 None
# 6       B012YX2ZPI   None   Usually ships in 4-5 business days
# 7       B074GPTP3J   None                                 None
# 8       B06Y2LCC5S   None                                 None
# 9       B00T9W4E66   None                                 None
# 10      B073Y91FTS   None                                 None
# 11      B001LOUGE4   None                                 None
# 12      B0751PWCP7   None                                 None
# 13      B0747M995P   None                                 None
# 14      B01LQAINPG   None                                 None
# 15      B003BSRPB0   None  Usually ships in 6-10 business days
# 16      B00L3C0O2S   None                                 None
# 17      B00XIM7A1Y   None                                 None
# 18      B06XKGTX6F   None                                 None
# 19      B01HMCZP80   None                                 None
# 20      B00XGI2REA   None                                 None
# 21      B014ICEDNA   None   Usually ships in 4-5 business days
# 22      B01KKVZM88   None                                 None
# 23      B01N8YY9G1   None                                 None
# 24      B071FKC36P   None                                 None
# 25      B009W1HUG0   None                                 None
# 26      B073S96HSS   None                                 None
# 27      B014ICEJ1Q   None   Usually ships in 4-5 business days
# 28      B074DF831N   None                                 None
# 29      B01GE1M4M0   None                                 None
# ...            ...    ...                                  ...
# 183108  B06WLNR267   None  Usually ships in 6-10 business days
# 183109  B010R8I8NA   None   Usually ships in 1-2 business days
# 183110  B073YGRLSM   None   Usually ships in 2-3 business days
# 183111  B06XJ24BWH   None                                 None
# 183112  B06XY2DZCT   None                                 None
# 183113  B01A51IYDI   None                                 None
# 183114  B07579G728   None                                 None
# 183115  B071D9X1S9   None                                 None
# 183116  B0749B51LK   None                                 None
# 183117  B01MS41A4S   None                                 None
# 183118  B01LSBZB8A   None                                 None
# 183119  B06W53LT7P   None                                 None
# 183120  B01NCO06S0   None   Usually ships in 1-2 business days
# 183121  B074PNHL3P   None                                 None
# 183122  B073PYBR49   None                                 None
# 183123  B073GH8CKH   None                                 None
# 183124  B01AVN150E   None   Usually ships in 1-2 business days
# 183125  B073HZ4BLC   None                                 None
# 183126  B073N5YT66   None                                 None
# 183127  B00CAOHGO2   None                                 None
# 183128  B01IWXIBNO   None                                 None
# 183129  B06XVRZBDL   None                                 None
# 183130  B074VX7YVN   None                                 None
# 183131  B071V9D3MH   None                                 None
# 183132  B074GSTF5S   None                                 None
# 183133  B01MSALTSO   None   Usually ships in 1-2 business days
# 183134  B015W98YQK   None                                 None
# 183135  B075756PGC   None                                 None
# 183136  B074L8FVTT   None   Usually ships in 2-3 business days
# 183137  B074FTYJQC   None                                 None
#
#        availability_type                        brand              color  \
# 0                   None                        FNC7C               None
# 1                   None                 FIG Clothing               None
# 2                   None                 FIG Clothing               None
# 3                   None                      Focal18               None
# 4                    now                  FeatherLite  Onyx Black/ Stone
# 5                   None                    Fitscloth              Grape
# 6                    now  HX-Kingdom Fashion T-shirts              White
# 7                   None                      Floerns               None
# 8                   None                  Fashion2ne1              Black
# 9                   None                         Fila               None
# 10                  None                      Floerns               None
# 11                  None                 Fitness Etc.              Black
# 12                  None               FIFTEEN TWENTY               None
# 13                  None                  Tee Fashion               None
# 14                  None                 Fedi Apparel               None
# 15                   now                  FeatherLite              White
# 16                  None            FEA Merchandising              Light
# 17                  None                         FIFA               Grey
# 18                  None                      Floerns               None
# 19                  None                 Fedi Apparel               None
# 20                  None            Fight Like a Girl               None
# 21                   now                        FNC7C             Purple
# 22                  None                       FDPlus              Black
# 23                  None                    Fifth Sun     Purple Heather
# 24                  None       Fifth Parallel Threads               None
# 25                  None            Alivila.Y Fashion               None
# 26                  None                    Fifth Sun             Cancun
# 27                   now                        FNC7C             Purple
# 28                  None               Fast & Furious               None
# 29                  None                       Firebo               None
# ...                  ...                          ...                ...
# 183108               now                     Shawhuaa               Rosy
# 183109               now                  GreaterGood          Turquoise
# 183110               now              Sky and Sparrow               Rose
# 183111              None                      Hibluco               None
# 183112              None                        Hatop              Brown
# 183113              None                       Tribal               None
# 183114              None                   Three Dots               None
# 183115              None                 Studio Works               None
# 183116              None                         YUNY               None
# 183117              None            Solution Clothing               None
# 183118              None                     Paixpays               None
# 183119              None                          XQS               None
# 183120               now                  Faded Glory          Blue/Grey
# 183121              None                        Romwe               None
# 183122              None                      WILLTOO              Black
# 183123              None                       uxcell               None
# 183124               now               Sacred Threads              Multi
# 183125              None                        Fulok               None
# 183126              None                          XQS               None
# 183127              None              U.S. Polo Assn.               None
# 183128              None   Velvet by Graham & Spencer               None
# 183129              None                     HaoDuoYi               None
# 183130              None                     Winwinus               None
# 183131              None                    Jingjing1               None
# 183132              None                  Ulla Popken               None
# 183133               now                    TOOGOO(R)              Black
# 183134              None                   VOGUE CODE   Monochrome Plaid
# 183135              None                     Wrangler               Pink
# 183136               now                susana monaco               Rose
# 183137              None                     Sexybaby               None
#
#                                          editorial_reivew  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 183108  These tank tops are light and breezy comfortab...
# 183109  The spirit of freedom comes alive in every thr...
# 183110  Sky and Sparrow Grommet Lace Up top. Off the s...
# 183111  Hibluco,advocate minimalist fashion brand.<br>...
# 183112  Item specifics <br> Gender:Women <br> Season:S...
# 183113               Tribal Sleeveless Pleat Front Blouse
# 183114  This Three Dots Blouse is guaranteed authentic...
# 183115  Exclusively ours! Create a sleek, bold style w...
# 183116  Hi buyer, pls pay attention, pls read our size...
# 183117  Short Sleeves, Zip Lining, Back Zip, Sexy Shap...
# 183118  1.100% brand new and good quality.<br>2.Suitab...
# 183119  <br>Dear buyer, we are new but grow rapidly, 9...
# 183120  Faded Glory Women's Plaid Tunic Shirt: 100% ra...
# 183121  Size Chart: <br> One-size:Shoulder:15.7 inch, ...
# 183122  <br /> 100% brand new and high quality <br /> ...
# 183123  • Bring a touch of edgy appeal to your new sea...
# 183124  This 100% poly-blend top is butterfly style, h...
# 183125  Tag Size is Asia size, it is smaller than Amer...
# 183126  <br>Dear buyer, we are new but grow rapidly, 9...
# 183127                            Button down woven shirt
# 183128  Challis long sleeve boat neck blouse with smoc...
# 183129  <br>-Customization and fashion design makes th...
# 183130  <br>China size, pls compare carefully before p...
# 183131  <b>Size Chart:</b><br> S:-----Shoulder 11.3"--...
# 183132  Stay cool & stylish in this lightweight layeri...
# 183133  <b>* TOOGOO is a registered trademark. ONLY Au...
# 183134  SIZE CHART <p> XS for length of front 27.6"; l...
# 183135  Pretty pink print button down Western shirt fr...
# 183136  Color/pattern: rose. Approximately 23in from s...
# 183137  Please check the measurement chart carefully. ...
#
#                                          editorial_review formatted_price  \
# 0       Minions Como Superheroes Ironman Women's O Nec...            None
# 1       Sizing runs on the small side. FIG® recommends...            None
# 2       Sizing runs on the small side. FIG® recommends...            None
# 3       100% Brand New & Fashion<br> Quantity: 1 Piece...            None
# 4                                                                  $26.26
# 5       Solid Modern Long Sleeve Tee. Quality Cotton T...            None
# 6       This Personalized Special Olympics World Games...           $9.99
# 7       <strong>Size Chart: </strong><br><br> X-Small:...            None
# 8       Standing on His Promises Bling Bling Rhineston...            None
# 9       The Fila Tulip Tank features a sporty design w...            None
# 10      <strong>Size Chart: </strong><br><br> <strong>...            None
# 11      Light Weight 2x1 Boy Beater Tank Top.  Great t...          $11.99
# 12      Fifteen Twenty's Grommet top features long bel...            None
# 13      This Short Sleeve Tee Will Take Your Casual We...            None
# 14      *Brand Name:</b> Fedi Apparel </b>(We are a Re...            None
# 15      FeatherLite Ladies' Moisture Free Mesh Sport S...          $20.54
# 16           Officially licensed Florida Georgia line tee            None
# 17      Show your team pride! This Old Glory design is...            None
# 18      Size Chart: <br> <br> <br>White:<br> Length(in...            None
# 19      Brand Name: Fedi Apparel(We are a Brand for go...            None
# 20      Breast cancer survivors and warriors, let canc...            None
# 21      Supernatural Chibis Sam Dean And Castiel Women...           $7.50
# 22      MEASUREMENTS <br>1X - Bust (seam to seam) - 22...            None
# 23      Celebrate your favorite heroes in a half-shell...            None
# 24      <br><b>MEASUREMENTS</b><br><br><b>FPAWTTS025:<...            None
# 25      <b>Alivila.Y Fashion Mesh Sequins Long Sleeve ...            None
# 26      Show everyone your love for the circle of life...            None
# 27      Supernatural Chibis Sam Dean And Castiel Women...           $7.39
# 28      Officially Licensed Merchandise. Comes with a ...            None
# 29      The comfortable, easy-to-wear, soft cotton mak...            None
# ...                                                   ...             ...
# 183108                                                NaN          $16.99
# 183109                                                NaN          $28.95
# 183110                                                NaN          $26.99
# 183111                                                NaN            None
# 183112                                                NaN            None
# 183113                                                NaN            None
# 183114                                                NaN            None
# 183115                                                NaN            None
# 183116                                                NaN            None
# 183117                                                NaN            None
# 183118                                                NaN            None
# 183119                                                NaN            None
# 183120                                                NaN          $18.99
# 183121                                                NaN            None
# 183122                                                NaN            None
# 183123                                                NaN            None
# 183124                                                NaN          $22.00
# 183125                                                NaN            None
# 183126                                                NaN            None
# 183127                                                NaN            None
# 183128                                                NaN            None
# 183129                                                NaN            None
# 183130                                                NaN            None
# 183131                                                NaN            None
# 183132                                                NaN            None
# 183133                                                NaN          $14.58
# 183134                                                NaN            None
# 183135                                                NaN            None
# 183136                                                NaN          $44.99
# 183137                                                NaN            None
#
#                                           large_image_url  \
# 0       https://images-na.ssl-images-amazon.com/images...
# 1       https://images-na.ssl-images-amazon.com/images...
# 2       https://images-na.ssl-images-amazon.com/images...
# 3       https://images-na.ssl-images-amazon.com/images...
# 4       https://images-na.ssl-images-amazon.com/images...
# 5       https://images-na.ssl-images-amazon.com/images...
# 6       https://images-na.ssl-images-amazon.com/images...
# 7       https://images-na.ssl-images-amazon.com/images...
# 8       https://images-na.ssl-images-amazon.com/images...
# 9       https://images-na.ssl-images-amazon.com/images...
# 10      https://images-na.ssl-images-amazon.com/images...
# 11      https://images-na.ssl-images-amazon.com/images...
# 12      https://images-na.ssl-images-amazon.com/images...
# 13      https://images-na.ssl-images-amazon.com/images...
# 14      https://images-na.ssl-images-amazon.com/images...
# 15      https://images-na.ssl-images-amazon.com/images...
# 16      https://images-na.ssl-images-amazon.com/images...
# 17      https://images-na.ssl-images-amazon.com/images...
# 18      https://images-na.ssl-images-amazon.com/images...
# 19      https://images-na.ssl-images-amazon.com/images...
# 20      https://images-na.ssl-images-amazon.com/images...
# 21      https://images-na.ssl-images-amazon.com/images...
# 22      https://images-na.ssl-images-amazon.com/images...
# 23      https://images-na.ssl-images-amazon.com/images...
# 24      https://images-na.ssl-images-amazon.com/images...
# 25      https://images-na.ssl-images-amazon.com/images...
# 26      https://images-na.ssl-images-amazon.com/images...
# 27      https://images-na.ssl-images-amazon.com/images...
# 28      https://images-na.ssl-images-amazon.com/images...
# 29      https://images-na.ssl-images-amazon.com/images...
# ...                                                   ...
# 183108  https://images-na.ssl-images-amazon.com/images...
# 183109  https://images-na.ssl-images-amazon.com/images...
# 183110  https://images-na.ssl-images-amazon.com/images...
# 183111  https://images-na.ssl-images-amazon.com/images...
# 183112  https://images-na.ssl-images-amazon.com/images...
# 183113  https://images-na.ssl-images-amazon.com/images...
# 183114  https://images-na.ssl-images-amazon.com/images...
# 183115  https://images-na.ssl-images-amazon.com/images...
# 183116  https://images-na.ssl-images-amazon.com/images...
# 183117  https://images-na.ssl-images-amazon.com/images...
# 183118  https://images-na.ssl-images-amazon.com/images...
# 183119  https://images-na.ssl-images-amazon.com/images...
# 183120  https://images-na.ssl-images-amazon.com/images...
# 183121  https://images-na.ssl-images-amazon.com/images...
# 183122  https://images-na.ssl-images-amazon.com/images...
# 183123  https://images-na.ssl-images-amazon.com/images...
# 183124  https://images-na.ssl-images-amazon.com/images...
# 183125  https://images-na.ssl-images-amazon.com/images...
# 183126  https://images-na.ssl-images-amazon.com/images...
# 183127  https://images-na.ssl-images-amazon.com/images...
# 183128  https://images-na.ssl-images-amazon.com/images...
# 183129  https://images-na.ssl-images-amazon.com/images...
# 183130  https://images-na.ssl-images-amazon.com/images...
# 183131  https://images-na.ssl-images-amazon.com/images...
# 183132  https://images-na.ssl-images-amazon.com/images...
# 183133  https://images-na.ssl-images-amazon.com/images...
# 183134  https://images-na.ssl-images-amazon.com/images...
# 183135  https://images-na.ssl-images-amazon.com/images...
# 183136  https://images-na.ssl-images-amazon.com/images...
# 183137  https://images-na.ssl-images-amazon.com/images...
#
#                                          manufacturer  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                        FEA Juniors
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                          Fifth Sun
# 24                                               None
# 25                                               None
# 26                                          Fifth Sun
# 27                                               None
# 28                                               None
# 29                                               None
# ...                                               ...
# 183108                                           None
# 183109                                           None
# 183110                                Sky and Sparrow
# 183111                                           None
# 183112                                           None
# 183113                                           None
# 183114                                     Three Dots
# 183115                                           None
# 183116                                           None
# 183117                                           None
# 183118                                           None
# 183119                                           None
# 183120                                           None
# 183121                                           None
# 183122                                           None
# 183123                                         uxcell
# 183124                                           None
# 183125                                           None
# 183126                                           None
# 183127             U.S. Polo Assn. Juniors Sportswear
# 183128  VELVET BY GRAHAM & SPENCER Women's Collection
# 183129                                           None
# 183130                                           None
# 183131                                           None
# 183132                                    Ulla Popken
# 183133                                           None
# 183134                                           None
# 183135                                           None
# 183136                                  susana monaco
# 183137                                           None
#
#                                          medium_image_url              model  \
# 0       https://images-na.ssl-images-amazon.com/images...               None
# 1       https://images-na.ssl-images-amazon.com/images...               None
# 2       https://images-na.ssl-images-amazon.com/images...               None
# 3       https://images-na.ssl-images-amazon.com/images...               None
# 4       https://images-na.ssl-images-amazon.com/images...               None
# 5       https://images-na.ssl-images-amazon.com/images...             BL0002
# 6       https://images-na.ssl-images-amazon.com/images...               None
# 7       https://images-na.ssl-images-amazon.com/images...               None
# 8       https://images-na.ssl-images-amazon.com/images...               None
# 9       https://images-na.ssl-images-amazon.com/images...           TW151JE6
# 10      https://images-na.ssl-images-amazon.com/images...               None
# 11      https://images-na.ssl-images-amazon.com/images...               None
# 12      https://images-na.ssl-images-amazon.com/images...            3F17090
# 13      https://images-na.ssl-images-amazon.com/images...               None
# 14      https://images-na.ssl-images-amazon.com/images...               None
# 15      https://images-na.ssl-images-amazon.com/images...               None
# 16      https://images-na.ssl-images-amazon.com/images...              2F104
# 17      https://images-na.ssl-images-amazon.com/images...               None
# 18      https://images-na.ssl-images-amazon.com/images...               None
# 19      https://images-na.ssl-images-amazon.com/images...               None
# 20      https://images-na.ssl-images-amazon.com/images...               None
# 21      https://images-na.ssl-images-amazon.com/images...               None
# 22      https://images-na.ssl-images-amazon.com/images...               None
# 23      https://images-na.ssl-images-amazon.com/images...  TMNT0013-60077010
# 24      https://images-na.ssl-images-amazon.com/images...               None
# 25      https://images-na.ssl-images-amazon.com/images...               None
# 26      https://images-na.ssl-images-amazon.com/images...  PXLK0013-60077005
# 27      https://images-na.ssl-images-amazon.com/images...               None
# 28      https://images-na.ssl-images-amazon.com/images...               None
# 29      https://images-na.ssl-images-amazon.com/images...               None
# ...                                                   ...                ...
# 183108  https://images-na.ssl-images-amazon.com/images...               None
# 183109  https://images-na.ssl-images-amazon.com/images...              81627
# 183110  https://images-na.ssl-images-amazon.com/images...        30668638102
# 183111  https://images-na.ssl-images-amazon.com/images...               None
# 183112  https://images-na.ssl-images-amazon.com/images...               None
# 183113  https://images-na.ssl-images-amazon.com/images...             10612O
# 183114  https://images-na.ssl-images-amazon.com/images...               None
# 183115  https://images-na.ssl-images-amazon.com/images...               None
# 183116  https://images-na.ssl-images-amazon.com/images...               None
# 183117  https://images-na.ssl-images-amazon.com/images...              T7180
# 183118  https://images-na.ssl-images-amazon.com/images...          2008S0192
# 183119  https://images-na.ssl-images-amazon.com/images...               None
# 183120  https://images-na.ssl-images-amazon.com/images...               None
# 183121  https://images-na.ssl-images-amazon.com/images...               None
# 183122  https://images-na.ssl-images-amazon.com/images...     A-WILLTOO-3805
# 183123  https://images-na.ssl-images-amazon.com/images...               None
# 183124  https://images-na.ssl-images-amazon.com/images...           #215586D
# 183125  https://images-na.ssl-images-amazon.com/images...               None
# 183126  https://images-na.ssl-images-amazon.com/images...               None
# 183127  https://images-na.ssl-images-amazon.com/images...               None
# 183128  https://images-na.ssl-images-amazon.com/images...        HARRIETTE03
# 183129  https://images-na.ssl-images-amazon.com/images...               None
# 183130  https://images-na.ssl-images-amazon.com/images...               None
# 183131  https://images-na.ssl-images-amazon.com/images...               None
# 183132  https://images-na.ssl-images-amazon.com/images...             712277
# 183133  https://images-na.ssl-images-amazon.com/images...           089106A4
# 183134  https://images-na.ssl-images-amazon.com/images...               None
# 183135  https://images-na.ssl-images-amazon.com/images...            LGS7089
# 183136  https://images-na.ssl-images-amazon.com/images...               None
# 183137  https://images-na.ssl-images-amazon.com/images...               None
#
#        product_type_name                                      publisher  \
# 0                  SHIRT                                           None
# 1                  SHIRT                                           None
# 2                  SHIRT                                           None
# 3                  SHIRT                                           None
# 4                  SHIRT                                           None
# 5                  SHIRT                                           None
# 6                  SHIRT                                           None
# 7                  SHIRT                                           None
# 8                  SHIRT                                           None
# 9                  SHIRT                                           None
# 10                 SHIRT                                           None
# 11                 SHIRT                                           None
# 12                 SHIRT                                           None
# 13                 SHIRT                                           None
# 14                 SHIRT                                           None
# 15                 SHIRT                                           None
# 16                 SHIRT                                    FEA Juniors
# 17                 SHIRT                                           None
# 18                 SHIRT                                           None
# 19                 SHIRT                                           None
# 20                 SHIRT                                           None
# 21                 SHIRT                                           None
# 22                 SHIRT                                           None
# 23                 SHIRT                                      Fifth Sun
# 24                 SHIRT                                           None
# 25               SWEATER                                           None
# 26                 SHIRT                                      Fifth Sun
# 27                 SHIRT                                           None
# 28                 SHIRT                                           None
# 29                 SHIRT                                           None
# ...                  ...                                            ...
# 183108             SHIRT                                           None
# 183109             SHIRT                                           None
# 183110             SHIRT                                Sky and Sparrow
# 183111             SHIRT                                           None
# 183112             SHIRT                                           None
# 183113             SHIRT                                           None
# 183114             SHIRT                                     Three Dots
# 183115             SHIRT                                           None
# 183116             SHIRT                                           None
# 183117             SHIRT                                           None
# 183118             DRESS                                           None
# 183119             SHIRT                                           None
# 183120             SHIRT                                           None
# 183121             SHIRT                                           None
# 183122             SHIRT                                           None
# 183123             SHIRT                                         uxcell
# 183124             SHIRT                                           None
# 183125             SHIRT                                           None
# 183126             SHIRT                                           None
# 183127             SHIRT             U.S. Polo Assn. Juniors Sportswear
# 183128             SHIRT  VELVET BY GRAHAM & SPENCER Women's Collection
# 183129             SHIRT                                           None
# 183130             SHIRT                                           None
# 183131             SHIRT                                           None
# 183132             SHIRT                                    Ulla Popken
# 183133         OUTERWEAR                                           None
# 183134             SHIRT                                           None
# 183135             SHIRT                                           None
# 183136             SHIRT                                  susana monaco
# 183137             SHIRT                                           None
#
#                                                   reviews  \
# 0       [False, https://www.amazon.com/reviews/iframe?...
# 1       [False, https://www.amazon.com/reviews/iframe?...
# 2       [False, https://www.amazon.com/reviews/iframe?...
# 3       [True, https://www.amazon.com/reviews/iframe?a...
# 4       [False, https://www.amazon.com/reviews/iframe?...
# 5       [False, https://www.amazon.com/reviews/iframe?...
# 6       [False, https://www.amazon.com/reviews/iframe?...
# 7       [True, https://www.amazon.com/reviews/iframe?a...
# 8       [False, https://www.amazon.com/reviews/iframe?...
# 9       [True, https://www.amazon.com/reviews/iframe?a...
# 10      [True, https://www.amazon.com/reviews/iframe?a...
# 11      [False, https://www.amazon.com/reviews/iframe?...
# 12      [False, https://www.amazon.com/reviews/iframe?...
# 13      [False, https://www.amazon.com/reviews/iframe?...
# 14      [False, https://www.amazon.com/reviews/iframe?...
# 15      [False, https://www.amazon.com/reviews/iframe?...
# 16      [True, https://www.amazon.com/reviews/iframe?a...
# 17      [False, https://www.amazon.com/reviews/iframe?...
# 18      [True, https://www.amazon.com/reviews/iframe?a...
# 19      [False, https://www.amazon.com/reviews/iframe?...
# 20      [True, https://www.amazon.com/reviews/iframe?a...
# 21      [True, https://www.amazon.com/reviews/iframe?a...
# 22      [False, https://www.amazon.com/reviews/iframe?...
# 23      [True, https://www.amazon.com/reviews/iframe?a...
# 24      [True, https://www.amazon.com/reviews/iframe?a...
# 25      [True, https://www.amazon.com/reviews/iframe?a...
# 26      [False, https://www.amazon.com/reviews/iframe?...
# 27      [False, https://www.amazon.com/reviews/iframe?...
# 28      [False, https://www.amazon.com/reviews/iframe?...
# 29      [False, https://www.amazon.com/reviews/iframe?...
# ...                                                   ...
# 183108  [False, https://www.amazon.com/reviews/iframe?...
# 183109  [False, https://www.amazon.com/reviews/iframe?...
# 183110  [False, https://www.amazon.com/reviews/iframe?...
# 183111  [True, https://www.amazon.com/reviews/iframe?a...
# 183112  [False, https://www.amazon.com/reviews/iframe?...
# 183113  [False, https://www.amazon.com/reviews/iframe?...
# 183114  [False, https://www.amazon.com/reviews/iframe?...
# 183115  [False, https://www.amazon.com/reviews/iframe?...
# 183116  [False, https://www.amazon.com/reviews/iframe?...
# 183117  [False, https://www.amazon.com/reviews/iframe?...
# 183118  [False, https://www.amazon.com/reviews/iframe?...
# 183119  [True, https://www.amazon.com/reviews/iframe?a...
# 183120  [False, https://www.amazon.com/reviews/iframe?...
# 183121  [False, https://www.amazon.com/reviews/iframe?...
# 183122  [False, https://www.amazon.com/reviews/iframe?...
# 183123  [False, https://www.amazon.com/reviews/iframe?...
# 183124  [False, https://www.amazon.com/reviews/iframe?...
# 183125  [False, https://www.amazon.com/reviews/iframe?...
# 183126  [False, https://www.amazon.com/reviews/iframe?...
# 183127  [True, https://www.amazon.com/reviews/iframe?a...
# 183128  [False, https://www.amazon.com/reviews/iframe?...
# 183129  [True, https://www.amazon.com/reviews/iframe?a...
# 183130  [False, https://www.amazon.com/reviews/iframe?...
# 183131  [False, https://www.amazon.com/reviews/iframe?...
# 183132  [False, https://www.amazon.com/reviews/iframe?...
# 183133  [False, https://www.amazon.com/reviews/iframe?...
# 183134  [False, https://www.amazon.com/reviews/iframe?...
# 183135  [False, https://www.amazon.com/reviews/iframe?...
# 183136  [False, https://www.amazon.com/reviews/iframe?...
# 183137  [False, https://www.amazon.com/reviews/iframe?...
#
#                          sku  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
# 10                      None
# 11                      None
# 12                      None
# 13                      None
# 14                      None
# 15      HT-2001_Lime-1149-XL
# 16                      None
# 17                      None
# 18                      None
# 19                      None
# 20                      None
# 21                      None
# 22                      None
# 23                      None
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                      None
# 29                      None
# ...                      ...
# 183108                  None
# 183109                  None
# 183110                  None
# 183111                  None
# 183112                  None
# 183113                  None
# 183114                  None
# 183115                  None
# 183116                  None
# 183117                  None
# 183118                  None
# 183119                  None
# 183120                  None
# 183121                  None
# 183122                  None
# 183123                  None
# 183124                  None
# 183125                  None
# 183126                  None
# 183127                  None
# 183128                  None
# 183129                  None
# 183130                  None
# 183131                  None
# 183132                  None
# 183133                  None
# 183134                  None
# 183135                  None
# 183136                  None
# 183137                  None
#
#                                           small_image_url  \
# 0       https://images-na.ssl-images-amazon.com/images...
# 1       https://images-na.ssl-images-amazon.com/images...
# 2       https://images-na.ssl-images-amazon.com/images...
# 3       https://images-na.ssl-images-amazon.com/images...
# 4       https://images-na.ssl-images-amazon.com/images...
# 5       https://images-na.ssl-images-amazon.com/images...
# 6       https://images-na.ssl-images-amazon.com/images...
# 7       https://images-na.ssl-images-amazon.com/images...
# 8       https://images-na.ssl-images-amazon.com/images...
# 9       https://images-na.ssl-images-amazon.com/images...
# 10      https://images-na.ssl-images-amazon.com/images...
# 11      https://images-na.ssl-images-amazon.com/images...
# 12      https://images-na.ssl-images-amazon.com/images...
# 13      https://images-na.ssl-images-amazon.com/images...
# 14      https://images-na.ssl-images-amazon.com/images...
# 15      https://images-na.ssl-images-amazon.com/images...
# 16      https://images-na.ssl-images-amazon.com/images...
# 17      https://images-na.ssl-images-amazon.com/images...
# 18      https://images-na.ssl-images-amazon.com/images...
# 19      https://images-na.ssl-images-amazon.com/images...
# 20      https://images-na.ssl-images-amazon.com/images...
# 21      https://images-na.ssl-images-amazon.com/images...
# 22      https://images-na.ssl-images-amazon.com/images...
# 23      https://images-na.ssl-images-amazon.com/images...
# 24      https://images-na.ssl-images-amazon.com/images...
# 25      https://images-na.ssl-images-amazon.com/images...
# 26      https://images-na.ssl-images-amazon.com/images...
# 27      https://images-na.ssl-images-amazon.com/images...
# 28      https://images-na.ssl-images-amazon.com/images...
# 29      https://images-na.ssl-images-amazon.com/images...
# ...                                                   ...
# 183108  https://images-na.ssl-images-amazon.com/images...
# 183109  https://images-na.ssl-images-amazon.com/images...
# 183110  https://images-na.ssl-images-amazon.com/images...
# 183111  https://images-na.ssl-images-amazon.com/images...
# 183112  https://images-na.ssl-images-amazon.com/images...
# 183113  https://images-na.ssl-images-amazon.com/images...
# 183114  https://images-na.ssl-images-amazon.com/images...
# 183115  https://images-na.ssl-images-amazon.com/images...
# 183116  https://images-na.ssl-images-amazon.com/images...
# 183117  https://images-na.ssl-images-amazon.com/images...
# 183118  https://images-na.ssl-images-amazon.com/images...
# 183119  https://images-na.ssl-images-amazon.com/images...
# 183120  https://images-na.ssl-images-amazon.com/images...
# 183121  https://images-na.ssl-images-amazon.com/images...
# 183122  https://images-na.ssl-images-amazon.com/images...
# 183123  https://images-na.ssl-images-amazon.com/images...
# 183124  https://images-na.ssl-images-amazon.com/images...
# 183125  https://images-na.ssl-images-amazon.com/images...
# 183126  https://images-na.ssl-images-amazon.com/images...
# 183127  https://images-na.ssl-images-amazon.com/images...
# 183128  https://images-na.ssl-images-amazon.com/images...
# 183129  https://images-na.ssl-images-amazon.com/images...
# 183130  https://images-na.ssl-images-amazon.com/images...
# 183131  https://images-na.ssl-images-amazon.com/images...
# 183132  https://images-na.ssl-images-amazon.com/images...
# 183133  https://images-na.ssl-images-amazon.com/images...
# 183134  https://images-na.ssl-images-amazon.com/images...
# 183135  https://images-na.ssl-images-amazon.com/images...
# 183136  https://images-na.ssl-images-amazon.com/images...
# 183137  https://images-na.ssl-images-amazon.com/images...
#
#                                                     title
# 0       Minions Como Superheroes Ironman Long Sleeve R...
# 1                           FIG Clothing Womens Izo Tunic
# 2                             FIG Clothing Womens Won Top
# 3       Focal18 Sailor Collar Bubble Sleeve Blouse Shi...
# 4       Featherlite Ladies' Long Sleeve Stain Resistan...
# 5       [Fits Cloth] Grape Solid Modern Long Sleeve Pl...
# 6       Women's Unique 100% Cotton T - Special Olympic...
# 7       Floerns Women's Bell Sleeve Beading Casual Blo...
# 8       Standing on His Promises Rhinestones T-Shirt R...
# 9       Fila Women's Tulip Durable Tennis Style Comfor...
# 10      Floerns Women's Cold Shoulder Casual Print Ruf...
# 11                 Ladies Cotton Tank 2x1 Ribbed Tank Top
# 12         Fifteen Twenty Grommet Tie Sleeve Top in Black
# 13      Yellow Women T Shirt,dance Cotton Short Sleeve...
# 14      Fedi Apparel Womens V-neck Long Sleeve Tops Ca...
# 15      FeatherLite Ladies' Moisture Free Mesh Sport S...
# 16      FEA Merchandising Juniors Florida Georgia Line...
# 17       World Cup USA Heather Grey Juniors Soft Tank Top
# 18      Floerns Women's Flower Embroidered Side Slit S...
# 19      Fedi Apparel Women Summer Chiffon Blouse Sleev...
# 20      Cancer Messed With Wrong Chick Breast Cancer T...
# 21      Supernatural Chibis Sam Dean And Castiel Short...
# 22      Sexy Open Shoulder X Long Soft Shark Hemline W...
# 23      Teenage Mutant Ninja Turtles Group Wave Womens...
# 24      FPT Womens Basic Casual Short Sleeve Round Nec...
# 25      Alivila.Y Fashion Womens Mesh Sequins Long Sle...
# 26      Fifth Sun Women's Lion King Hakuna Matata Prin...
# 27      Supernatural Chibis Sam Dean And Castiel O Nec...
# 28      Officially Licensed Fast & Furious - Est. 2007...
# 29      Firebo Billy Joel In Concert 2016 Short Sleeve...
# ...                                                   ...
# 183108  Womens Basic Loose Low V Neck Racerback Sport ...
# 183109                                 Tie Dye Spirit Top
# 183110   SKY AND SPARROW Grommet Lace Up Top, Rose, Small
# 183111  Hibluco Women's Sexy V-neck Crop Tops Backless...
# 183112  Blouse, Hatop Womens Sexy Off Shoulder Irregul...
# 183113               Tribal Sleeveless Pleat Front Blouse
# 183114          Three Dots Womens Gathered Pleated Blouse
# 183115                    Studio Works Printed Poncho Top
# 183116  YUNY Women Casual Denim Patchwork Plaid Shirt ...
# 183117     Bangbangusa Women One Golden Star Back Zip Top
# 183118  Women Long Sleeve Denim Blue Casual Shirt Blou...
# 183119  XQS Women's Solid Basic Chiffon Casual Shirts ...
# 183120  Faded Glory Women's Plaid Button Down 2 Pocket...
# 183121  ROMWE Women's Floral Embroidered Long Sleeve B...
# 183122  New! WILLTOO Women V Neck Long Sleeve Blouse F...
# 183123  Agnes Orinda Women's Plus Size Asymmetric Hem ...
# 183124  Printed Top in Assorted Colors – One size #215...
# 183125  Fulok Women Rainbow Long Sleeve Blouse Button ...
# 183126  XQS Womens Irregular hem Sleeveless Slim Fit t...
# 183127          U.S. Polo Assn. Juniors Woven Plaid Shirt
# 183128  VELVET BY GRAHAM & SPENCER Women's Rayon Chall...
# 183129  HaoDuoYi Womens Basic Cut Out Top T Shirt with...
# 183130  Winwinus Womens Bow-knot Bandage Long Sleeve B...
# 183131  Women's Cold Shoulder Button Down Shirt, Long ...
# 183132  Ulla Popken Women's Plus Size Crochet Lace Acc...
# 183133  TOOGOO(R) Women's Tops Spring Autumn Casual Pu...
# 183134  VOGUE CODE Vintage V Neck Plaid Shirt Sleevele...
# 183135  Wrangler George Strait For Her Long Sleeve Pin...
# 183136  Susana Monaco Womens Susana Monoco Sleeveless ...
# 183137  SexyBaby Women's Mesh Splive Flounced Sleeve C...
#
# [183138 rows x 19 columns]

# %%
print(data.shape[0],data.shape[1])
# Out:
# 183138 19

# %%
data.columns
# Out:
# Index(['asin', 'author', 'availability', 'availability_type', 'brand', 'color',
#        'editorial_reivew', 'editorial_review', 'formatted_price',
#        'large_image_url', 'manufacturer', 'medium_image_url', 'model',
#        'product_type_name', 'publisher', 'reviews', 'sku', 'small_image_url',
#        'title'],
#       dtype='object')

# %%
data = data[['asin', 'brand', 'color', 'medium_image_url', 'product_type_name', 'title', 'formatted_price']]

# %%
data.head()
# Out:
#          asin         brand              color  \
# 0  B016I2TS4W         FNC7C               None
# 1  B01N49AI08  FIG Clothing               None
# 2  B01JDPCOHO  FIG Clothing               None
# 3  B01N19U5H5       Focal18               None
# 4  B004GSI2OS   FeatherLite  Onyx Black/ Stone
#
#                                     medium_image_url product_type_name  \
# 0  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 1  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 2  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 3  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 4  https://images-na.ssl-images-amazon.com/images...             SHIRT
#
#                                                title formatted_price
# 0  Minions Como Superheroes Ironman Long Sleeve R...            None
# 1                      FIG Clothing Womens Izo Tunic            None
# 2                        FIG Clothing Womens Won Top            None
# 3  Focal18 Sailor Collar Bubble Sleeve Blouse Shi...            None
# 4  Featherlite Ladies' Long Sleeve Stain Resistan...          $26.26

# %%
print(data['product_type_name'].describe())
# Out:
# count     183138
# unique        72
# top        SHIRT
# freq      167794
# Name: product_type_name, dtype: object

# %%
print(data['product_type_name'].unique())
# Out:
# ['SHIRT' 'SWEATER' 'APPAREL' 'OUTDOOR_RECREATION_PRODUCT'
#  'BOOKS_1973_AND_LATER' 'PANTS' 'HAT' 'SPORTING_GOODS' 'DRESS' 'UNDERWEAR'
#  'SKIRT' 'OUTERWEAR' 'BRA' 'ACCESSORY' 'ART_SUPPLIES' 'SLEEPWEAR'
#  'ORCA_SHIRT' 'HANDBAG' 'PET_SUPPLIES' 'SHOES' 'KITCHEN' 'ADULT_COSTUME'
#  'HOME_BED_AND_BATH' 'MISC_OTHER' 'BLAZER' 'HEALTH_PERSONAL_CARE'
#  'TOYS_AND_GAMES' 'SWIMWEAR' 'CONSUMER_ELECTRONICS' 'SHORTS' 'HOME'
#  'AUTO_PART' 'OFFICE_PRODUCTS' 'ETHNIC_WEAR' 'BEAUTY'
#  'INSTRUMENT_PARTS_AND_ACCESSORIES' 'POWERSPORTS_PROTECTIVE_GEAR' 'SHIRTS'
#  'ABIS_APPAREL' 'AUTO_ACCESSORY' 'NONAPPARELMISC' 'TOOLS' 'BABY_PRODUCT'
#  'SOCKSHOSIERY' 'POWERSPORTS_RIDING_SHIRT' 'EYEWEAR' 'SUIT'
#  'OUTDOOR_LIVING' 'POWERSPORTS_RIDING_JACKET' 'HARDWARE' 'SAFETY_SUPPLY'
#  'ABIS_DVD' 'VIDEO_DVD' 'GOLF_CLUB' 'MUSIC_POPULAR_VINYL'
#  'HOME_FURNITURE_AND_DECOR' 'TABLET_COMPUTER' 'GUILD_ACCESSORIES'
#  'ABIS_SPORTS' 'ART_AND_CRAFT_SUPPLY' 'BAG' 'MECHANICAL_COMPONENTS'
#  'SOUND_AND_RECORDING_EQUIPMENT' 'COMPUTER_COMPONENT' 'JEWELRY'
#  'BUILDING_MATERIAL' 'LUGGAGE' 'BABY_COSTUME' 'POWERSPORTS_VEHICLE_PART'
#  'PROFESSIONAL_HEALTHCARE' 'SEEDS_AND_PLANTS' 'WIRELESS_ACCESSORY']

# %%
product_type_count = Counter((data['product_type_name']))
(product_type_count.most_common(10))
# Out:
# [('SHIRT', 167794),
#  ('APPAREL', 3549),
#  ('BOOKS_1973_AND_LATER', 3336),
#  ('DRESS', 1584),
#  ('SPORTING_GOODS', 1281),
#  ('SWEATER', 837),
#  ('OUTERWEAR', 796),
#  ('OUTDOOR_RECREATION_PRODUCT', 729),
#  ('ACCESSORY', 636),
#  ('UNDERWEAR', 425)]

# %%
data['brand'].describe()
# Out:
# count     182987
# unique     10577
# top         Zago
# freq         223
# Name: brand, dtype: object

# %%
brand_count = Counter((data['brand']))
brand_count.most_common(10)
# Out:
# [('Zago', 223),
#  ('XQS', 222),
#  ('Yayun', 215),
#  ('YUNY', 198),
#  ('XiaoTianXin-women clothes', 193),
#  ('Generic', 192),
#  ('Boohoo', 190),
#  ('Alion', 188),
#  ('Abetteric', 187),
#  ('TheMogan', 187)]

# %%
print(data['color'].describe())
# Out:
# count     64956
# unique     7380
# top       Black
# freq      13207
# Name: color, dtype: object

# %%
color_count = Counter(data['color'])
color_count.most_common(10)
# Out:
# [(None, 118182),
#  ('Black', 13207),
#  ('White', 8616),
#  ('Blue', 3570),
#  ('Red', 2289),
#  ('Pink', 1842),
#  ('Grey', 1499),
#  ('*', 1388),
#  ('Green', 1258),
#  ('Multi', 1203)]

# %%
data['formatted_price'].describe()
# Out:
# count      28395
# unique      3135
# top       $19.99
# freq         945
# Name: formatted_price, dtype: object

# %%
price_count = Counter(data['formatted_price'])
price_count.most_common(10)
# Out:
# [(None, 154743),
#  ('$19.99', 945),
#  ('$9.99', 749),
#  ('$9.50', 601),
#  ('$14.99', 472),
#  ('$7.50', 463),
#  ('$24.99', 414),
#  ('$29.99', 370),
#  ('$8.99', 343),
#  ('$9.01', 336)]

# %%
data['title'].describe()
# Out:
# count                                                183138
# unique                                               175985
# top       Nakoda Cotton Self Print Straight Kurti For Women
# freq                                                     77
# Name: title, dtype: object

# %%
data.to_pickle('pickles/180k_apparel_data')

# %%
data = data.loc[~data['formatted_price'].isnull()]
data.shape[0]
# Out:
# 28395

# %%
data = data.loc[~data['color'].isnull()]
data.shape[0]
# Out:
# 28385

# %%
data.to_pickle('pickles/28k_apparel_data')

# %%
# You can download all these 28k images using this code below.
# You do NOT need to run this code and hence it is commented.


'''
from PIL import Image
import requests
from io import BytesIO

for index, row in images.iterrows():
        url = row['large_image_url']
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
        img.save('images/28k_images/'+row['asin']+'.jpeg')


'''
# Out:
# "\nfrom PIL import Image\nimport requests\nfrom io import BytesIO\n\nfor index, row in images.iterrows():\n        url = row['large_image_url']\n        response = requests.get(url)\n        img = Image.open(BytesIO(response.content))\n        img.save('images/28k_images/'+row['asin']+'.jpeg')\n\n\n"

# %%
data = pd.read_pickle('pickles/28k_apparel_data')
(data.duplicated('title'))
print(sum(data.duplicated('title')))
# Out:
# 2325

# %%
data.head()
# Out:
#           asin                        brand              color  \
# 4   B004GSI2OS                  FeatherLite  Onyx Black/ Stone
# 6   B012YX2ZPI  HX-Kingdom Fashion T-shirts              White
# 11  B001LOUGE4                 Fitness Etc.              Black
# 15  B003BSRPB0                  FeatherLite              White
# 21  B014ICEDNA                        FNC7C             Purple
#
#                                      medium_image_url product_type_name  \
# 4   https://images-na.ssl-images-amazon.com/images...             SHIRT
# 6   https://images-na.ssl-images-amazon.com/images...             SHIRT
# 11  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 15  https://images-na.ssl-images-amazon.com/images...             SHIRT
# 21  https://images-na.ssl-images-amazon.com/images...             SHIRT
#
#                                                 title formatted_price
# 4   Featherlite Ladies' Long Sleeve Stain Resistan...          $26.26
# 6   Women's Unique 100% Cotton T - Special Olympic...           $9.99
# 11             Ladies Cotton Tank 2x1 Ribbed Tank Top          $11.99
# 15  FeatherLite Ladies' Moisture Free Mesh Sport S...          $20.54
# 21  Supernatural Chibis Sam Dean And Castiel Short...           $7.50

# %%
#Remove all products with very few words in title
data_sorted = data[data['title'].apply(lambda x : len(x.split()) > 4)]
data_sorted.shape
# Out:
# (27949, 7)

# %%
#Sort the whole data based on title (alphabetical order of title)
data_sorted.sort_values('title', inplace = True, ascending = False)

# %%
indices = []
for i,row in data_sorted.iterrows():
    indices.append(i)

indices
# Out:
# [61973,
#  133820,
#  81461,
#  75995,
#  151570,
#  152506,
#  76209,
#  103647,
#  138588,
#  95954,
#  74338,
#  18905,
#  60078,
#  59030,
#  177229,
#  22273,
#  135865,
#  171318,
#  44082,
#  40331,
#  60603,
#  56982,
#  39370,
#  120006,
#  8424,
#  139484,
#  94413,
#  167267,
#  92382,
#  93518,
#  101522,
#  74087,
#  51286,
#  35796,
#  73818,
#  127730,
#  37902,
#  164994,
#  125784,
#  129103,
#  161966,
#  151598,
#  100567,
#  102610,
#  80880,
#  74066,
#  167810,
#  100898,
#  86604,
#  153020,
#  168828,
#  97684,
#  83173,
#  37290,
#  17234,
#  130798,
#  128762,
#  38107,
#  32240,
#  141241,
#  37911,
#  142996,
#  115660,
#  163170,
#  73633,
#  132135,
#  42468,
#  69292,
#  32217,
#  169883,
#  108966,
#  68893,
#  115422,
#  141090,
#  80785,
#  92051,
#  165541,
#  150090,
#  163741,
#  123456,
#  57588,
#  116686,
#  170034,
#  160212,
#  144984,
#  142244,
#  141432,
#  118353,
#  101884,
#  110314,
#  140321,
#  76493,
#  135579,
#  85390,
#  78409,
#  158069,
#  148089,
#  100597,
#  140457,
#  137999,
#  147641,
#  94653,
#  120825,
#  145597,
#  114795,
#  98140,
#  148772,
#  80202,
#  113184,
#  79120,
#  93161,
#  86422,
#  103918,
#  157939,
#  99504,
#  85577,
#  133860,
#  77972,
#  163080,
#  84198,
#  143996,
#  155062,
#  135226,
#  80328,
#  89791,
#  118521,
#  98687,
#  99639,
#  82053,
#  115267,
#  160313,
#  163797,
#  142024,
#  119967,
#  124060,
#  135774,
#  74028,
#  130670,
#  113833,
#  55768,
#  41557,
#  46840,
#  21179,
#  60373,
#  28271,
#  17125,
#  147370,
#  152447,
#  150332,
#  17346,
#  122072,
#  171131,
#  43116,
#  64972,
#  119066,
#  78368,
#  87245,
#  97034,
#  152923,
#  70699,
#  154498,
#  99750,
#  99693,
#  146219,
#  69780,
#  121899,
#  19171,
#  17771,
#  46289,
#  45634,
#  48394,
#  173678,
#  42079,
#  173547,
#  43495,
#  43893,
#  41807,
#  49238,
#  40564,
#  60151,
#  6885,
#  39606,
#  30987,
#  56358,
#  62946,
#  101535,
#  40634,
#  56401,
#  33403,
#  63331,
#  21983,
#  35587,
#  66445,
#  66940,
#  28690,
#  28823,
#  49114,
#  30251,
#  43226,
#  172455,
#  133881,
#  143046,
#  20512,
#  96833,
#  137710,
#  175847,
#  31929,
#  161292,
#  45550,
#  33400,
#  24670,
#  101485,
#  158911,
#  118174,
#  176362,
#  180163,
#  177197,
#  179396,
#  87892,
#  88177,
#  114419,
#  114533,
#  66210,
#  54003,
#  161360,
#  84312,
#  16626,
#  57478,
#  87406,
#  19217,
#  64003,
#  56566,
#  56338,
#  20933,
#  24316,
#  20971,
#  173681,
#  50941,
#  59832,
#  37616,
#  66480,
#  5620,
#  89300,
#  6384,
#  133671,
#  134479,
#  106995,
#  157218,
#  79388,
#  119306,
#  16335,
#  24074,
#  6377,
#  20741,
#  27926,
#  24751,
#  59735,
#  25579,
#  16908,
#  17004,
#  35024,
#  46192,
#  53012,
#  63809,
#  62130,
#  34464,
#  47043,
#  50487,
#  33617,
#  35132,
#  40349,
#  18644,
#  37379,
#  55519,
#  35821,
#  55946,
#  67060,
#  51210,
#  40535,
#  65765,
#  86979,
#  78376,
#  87953,
#  101412,
#  110097,
#  159332,
#  128661,
#  130441,
#  80870,
#  153599,
#  88624,
#  112285,
#  122529,
#  145894,
#  77625,
#  148947,
#  7939,
#  62732,
#  57089,
#  54246,
#  158027,
#  139898,
#  130193,
#  130941,
#  131626,
#  104080,
#  123451,
#  111351,
#  124340,
#  91714,
#  136509,
#  153679,
#  125245,
#  90955,
#  69925,
#  78733,
#  112185,
#  137451,
#  146361,
#  86519,
#  155911,
#  156685,
#  141004,
#  104556,
#  69984,
#  160251,
#  82125,
#  127118,
#  152166,
#  142470,
#  68048,
#  90952,
#  140520,
#  141128,
#  151425,
#  128211,
#  122113,
#  104505,
#  67808,
#  155013,
#  103375,
#  107128,
#  149718,
#  127601,
#  117714,
#  111512,
#  86007,
#  79764,
#  144300,
#  169626,
#  125532,
#  84094,
#  92451,
#  108985,
#  53185,
#  48607,
#  44000,
#  127909,
#  98282,
#  164992,
#  139912,
#  178281,
#  180905,
#  177823,
#  182879,
#  178902,
#  180846,
#  179370,
#  177564,
#  176684,
#  180484,
#  182836,
#  181064,
#  180451,
#  179928,
#  177127,
#  129531,
#  116697,
#  179213,
#  181629,
#  180342,
#  183028,
#  180913,
#  144062,
#  66257,
#  51856,
#  118719,
#  47658,
#  41438,
#  26180,
#  31602,
#  32480,
#  138269,
#  54310,
#  24290,
#  65494,
#  38979,
#  50503,
#  29615,
#  38048,
#  58137,
#  55105,
#  52891,
#  48696,
#  26167,
#  44342,
#  23641,
#  52543,
#  36738,
#  45336,
#  22110,
#  31163,
#  91255,
#  165018,
#  149477,
#  120210,
#  130243,
#  164518,
#  82062,
#  80766,
#  87998,
#  52688,
#  127098,
#  76783,
#  80351,
#  139334,
#  31343,
#  24323,
#  29056,
#  53968,
#  24839,
#  100974,
#  75614,
#  145585,
#  85304,
#  165561,
#  167309,
#  90911,
#  96763,
#  95328,
#  78300,
#  130658,
#  80890,
#  152588,
#  73385,
#  139056,
#  82419,
#  158753,
#  72381,
#  145730,
#  105107,
#  164247,
#  164314,
#  98483,
#  125947,
#  117730,
#  108387,
#  141304,
#  164541,
#  144620,
#  141294,
#  127428,
#  94106,
#  144720,
#  146889,
#  153525,
#  132991,
#  163185,
#  107198,
#  81551,
#  164778,
#  84351,
#  110425,
#  95922,
#  155039,
#  111791,
#  88751,
#  87432,
#  89137,
#  117530,
#  128826,
#  158739,
#  101255,
#  81983,
#  115963,
#  82459,
#  130020,
#  113247,
#  87799,
#  136212,
#  73423,
#  91930,
#  158391,
#  105223,
#  89730,
#  115465,
#  155333,
#  136648,
#  84566,
#  139504,
#  100878,
#  127141,
#  69095,
#  77032,
#  85023,
#  142725,
#  157201,
#  95188,
#  106623,
#  104644,
#  179842,
#  178872,
#  169133,
#  104160,
#  178743,
#  135448,
#  179102,
#  182457,
#  182411,
#  176722,
#  178498,
#  178552,
#  179846,
#  179543,
#  30079,
#  178686,
#  182551,
#  182034,
#  128186,
#  21173,
#  40067,
#  47827,
#  48021,
#  24921,
#  55481,
#  48885,
#  45251,
#  54275,
#  18008,
#  62448,
#  22411,
#  37415,
#  17768,
#  61174,
#  45788,
#  44339,
#  42636,
#  30933,
#  37172,
#  46360,
#  45332,
#  55465,
#  101061,
#  94879,
#  146186,
#  101677,
#  83320,
#  175912,
#  178574,
#  183081,
#  165045,
#  117541,
#  150098,
#  79375,
#  168750,
#  103886,
#  93763,
#  169018,
#  111366,
#  146178,
#  150840,
#  102286,
#  75857,
#  165689,
#  98566,
#  165293,
#  95031,
#  163762,
#  134577,
#  147753,
#  140792,
#  164352,
#  150228,
#  149634,
#  165201,
#  95522,
#  121143,
#  118642,
#  100387,
#  150894,
#  67306,
#  115101,
#  133506,
#  49951,
#  74807,
#  144981,
#  125513,
#  66502,
#  66557,
#  22259,
#  44763,
#  65816,
#  52778,
#  43103,
#  64807,
#  16667,
#  32735,
#  26807,
#  57268,
#  31465,
#  61083,
#  33920,
#  52916,
#  47746,
#  20507,
#  34890,
#  34466,
#  41905,
#  66546,
#  56932,
#  30119,
#  57963,
#  58315,
#  49559,
#  53402,
#  171092,
#  525,
#  17626,
#  22645,
#  35987,
#  52341,
#  39994,
#  32406,
#  47186,
#  21476,
#  168805,
#  177481,
#  149804,
#  180173,
#  109587,
#  151399,
#  92185,
#  160935,
#  111446,
#  124036,
#  76077,
#  142928,
#  72039,
#  94356,
#  96817,
#  115797,
#  127486,
#  146042,
#  136442,
#  70934,
#  154111,
#  159228,
#  145445,
#  160264,
#  80190,
#  77885,
#  154195,
#  161284,
#  113409,
#  120016,
#  156333,
#  121366,
#  139387,
#  91426,
#  167213,
#  122405,
#  158659,
#  114478,
#  100221,
#  133527,
#  149152,
#  111409,
#  127214,
#  126418,
#  160870,
#  78503,
#  131728,
#  86720,
#  128614,
#  163698,
#  130248,
#  123361,
#  131671,
#  165301,
#  141466,
#  81293,
#  75249,
#  121979,
#  158923,
#  128244,
#  82177,
#  149361,
#  120851,
#  121774,
#  118489,
#  94577,
#  143850,
#  138459,
#  74945,
#  73326,
#  67774,
#  160344,
#  140477,
#  71605,
#  143755,
#  127518,
#  113841,
#  134408,
#  131564,
#  94966,
#  128957,
#  135144,
#  170083,
#  133457,
#  80631,
#  155112,
#  111453,
#  122103,
#  72149,
#  79621,
#  68721,
#  108119,
#  74949,
#  94482,
#  169492,
#  75318,
#  112927,
#  65430,
#  61095,
#  58122,
#  62271,
#  179143,
#  46609,
#  177449,
#  51785,
#  32220,
#  108848,
#  68773,
#  114984,
#  94450,
#  111656,
#  128412,
#  111686,
#  114565,
#  100129,
#  123234,
#  178991,
#  30730,
#  31892,
#  24832,
#  24792,
#  55083,
#  27968,
#  20756,
#  44748,
#  65032,
#  65206,
#  42943,
#  51497,
#  144674,
#  111744,
#  89101,
#  128064,
#  149587,
#  154547,
#  93123,
#  117229,
#  79872,
#  160586,
#  145567,
#  148627,
#  149179,
#  75938,
#  95146,
#  157550,
#  167353,
#  153423,
#  85219,
#  135500,
#  150717,
#  83634,
#  68642,
#  78757,
#  68261,
#  131203,
#  170902,
#  89688,
#  154618,
#  165238,
#  97048,
#  92275,
#  105988,
#  143245,
#  168116,
#  116920,
#  140296,
#  135601,
#  94644,
#  101109,
#  152560,
#  76319,
#  138953,
#  151547,
#  106863,
#  71715,
#  137700,
#  143210,
#  146212,
#  84013,
#  80550,
#  77883,
#  132396,
#  111729,
#  119587,
#  170638,
#  77342,
#  136965,
#  93356,
#  98107,
#  150844,
#  28560,
#  35126,
#  57373,
#  41659,
#  57191,
#  19209,
#  47092,
#  111160,
#  81785,
#  149928,
#  138253,
#  105644,
#  176262,
#  177204,
#  176622,
#  180139,
#  180478,
#  152509,
#  159861,
#  125298,
#  149294,
#  89098,
#  115623,
#  123431,
#  150657,
#  83528,
#  90402,
#  132490,
#  122395,
#  108905,
#  107145,
#  151289,
#  79154,
#  102205,
#  167285,
#  103149,
#  163002,
#  79422,
#  162640,
#  142343,
#  104739,
#  87784,
#  129515,
#  68292,
#  78764,
#  86782,
#  101471,
#  146192,
#  90622,
#  96796,
#  105359,
#  126158,
#  83569,
#  99038,
#  69240,
#  92639,
#  71670,
#  86934,
#  166999,
#  148315,
#  138802,
#  111801,
#  110351,
#  110637,
#  150415,
#  84694,
#  168001,
#  89441,
#  163795,
#  80722,
#  129862,
#  32870,
#  21432,
#  176124,
#  97147,
#  157424,
#  139566,
#  144871,
#  100833,
#  125288,
#  108665,
#  35001,
#  41581,
#  54296,
#  19147,
#  50773,
#  28957,
#  30771,
#  58606,
#  36490,
#  44132,
#  34753,
#  41890,
#  21728,
#  50698,
#  34775,
#  22137,
#  27851,
#  17062,
#  56546,
#  17972,
#  51683,
#  38216,
#  63741,
#  46114,
#  17320,
#  65016,
#  65720,
#  23341,
#  50771,
#  27242,
#  37832,
#  33918,
#  32559,
#  49025,
#  20148,
#  60245,
#  58104,
#  28386,
#  50037,
#  66100,
#  48235,
#  33692,
#  45040,
#  24909,
#  56602,
#  19602,
#  22231,
#  39250,
#  47776,
#  33930,
#  56564,
#  45249,
#  58129,
#  56272,
#  61667,
#  51308,
#  54965,
#  33975,
#  63107,
#  30900,
#  53510,
#  45020,
#  30645,
#  51239,
#  148787,
#  161728,
#  137730,
#  150408,
#  124104,
#  108898,
#  100134,
#  91560,
#  88334,
#  84755,
#  163777,
#  143636,
#  133205,
#  120537,
#  85532,
#  98588,
#  161893,
#  108819,
#  107180,
#  128283,
#  98681,
#  111417,
#  127697,
#  149998,
#  148573,
#  116988,
#  126172,
#  163230,
#  146248,
#  177591,
#  ...]

# %%
import itertools
stage1_dedupe_asins = []
i = 0
j = 0
num_data_points = data_sorted.shape[0]
while i < num_data_points and j < num_data_points:
    previous_i = i
    
    a = data['title'].loc[indices[i]].split()
    
    j = i+1
    
    while j< num_data_points:
        
        b = data['title'].loc[indices[j]].split()
        
        length = max(len(a), len(b))
        
        count = 0;
        
        for k in itertools.zip_longest(a,b):
            if(k[0] == k[1]):
                count+=1
        
        if ( length-count) > 2:
            
            stage1_dedupe_asins.append(data_sorted['asin'].loc[indices[i]])
        
            if j == num_data_points-1:
                stage1_dedupe_asins.append(data_sorted['asin'].loc[indices[j]])
                
            i = j
            break
            
        else:
            j += 1
        
    if previous_i == i:
        break

# %%
data = data.loc[data['asin'].isin(stage1_dedupe_asins)]

# %%
data.shape
# Out:
# (17593, 7)

# %%
data.to_pickle('pickles/17k_apperal_data')

# %%
data = pd.read_pickle('pickles/17k_apperal_data')

# %%
indices = []
for i,row in data.iterrows():
    indices.append(i)


stage2_dedupe_asins = []
while len(indices) != 0:
    i = indices.pop()
    stage2_dedupe_asins.append(data['asin'].loc[i])
    
    a = data['title'].loc[i].split()
    
    for j in indices:
        
        b = data['title'].loc[j].split()
        
        
        length = max(len(a), len(b))
        
        count = 0
        
        for k in itertools.zip_longest(a,b):
            if( k[0] == k[1]):
                count+=1
        
        if (length - count) < 3:
            indices.remove(j)

# %%
data = data.loc[data['asin'].isin(stage2_dedupe_asins)]

# %%
data.shape

# %%
data.to_pickle('pickles/16k_apperal_data')

# %% [markdown]
# # Text Processing

# %%
data = pd.read_pickle('pickles/16k_apperal_data')

# %%
stop_words = set(stopwords.words('english'))
print("list of stop words : ", stop_words)

def nlp_preprocessing(total_text , index, column):
    if type(total_text) is not int:
        string = ""
        for words in total_text.split():
            word = ("".join(e for e in words if e.isalnum()))
            word = word.lower()
            
            if not word in stop_words:
                string += word + " "
            
        data[column][index] = string

# %%
start_time = time.clock()

for index, row in data.iterrows():
    nlp_preprocessing(row['title'], index, 'title')

print(time.clock() - start_time, " seconds")

# %%
data.head()

# %%
data.to_pickle('pickles/16k_apperal_data_preprocessed')

# %% [markdown]
# # Stemming
# ### stemming doesn't work very well

# %% [markdown]
# # Text based product similarity

# %%
data = pd.read_pickle('pickles/16k_apperal_data_preprocessed')
data.head()

# %%
#Display an image

def display_img(url, ax, fig):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    
#plotting code to understand the algo's decision
def plot_heatmap(keys, values, labels, url, text):
        # keys: list of words of recommended title
        # values: len(values) ==  len(keys), values(i) represents the occurence of the word keys(i)
        # labels: len(labels) == len(keys), the values of labels depends on the model we are using
                # if model == 'bag of words': labels(i) = values(i)
                # if model == 'tfidf weighted bag of words':labels(i) = tfidf(keys(i))
                # if model == 'idf weighted bag of words':labels(i) = idf(keys(i))
        # url : apparel's url

        # we will devide the whole figure into two parts
        gs = gridspec.GridSpec(2, 2, width_ratios=[4,1], height_ratios=[4,1]) 
        fig = plt.figure(figsize=(25,3))
        
        # 1st, ploting heat map that represents the count of commonly ocurred words in title2
        ax = plt.subplot(gs[0])
        # it displays a cell in white color if the word is intersection(lis of words of title1 and list of words of title2), in black if not
        ax = sns.heatmap(np.array([values]), annot=np.array([labels]))
        ax.set_xticklabels(keys) # set that axis labels as the words of title
        ax.set_title(text) # apparel title
        
        # 2nd, plotting image of the the apparel
        ax = plt.subplot(gs[1])
        # we don't want any grid lines for image and no labels on x-axis and y-axis
        ax.grid(False)
        ax.set_xticks([])
        ax.set_yticks([])
        
        # we call dispaly_img based with paramete url
        display_img(url, ax, fig)
        
        # displays combine figure ( heat map and image together)
        plt.show()

def plot_heatmap_image(doc_id, vec1, vec2, url, text, model):

    # doc_id : index of the title1
    # vec1 : input apparels's vector, it is of a dict type {word:count}
    # vec2 : recommended apparels's vector, it is of a dict type {word:count}
    # url : apparels image url
    # text: title of recomonded apparel (used to keep title of image)
    # model, it can be any of the models, 
        # 1. bag_of_words
        # 2. tfidf
        # 3. idf

    # we find the common words in both titles, because these only words contribute to the distance between two title vec's
    intersection = set(vec1.keys()) & set(vec2.keys()) 

    # we set the values of non intersecting words to zero, this is just to show the difference in heatmap
    for i in vec2:
        if i not in intersection:
            vec2[i]=0

    # for labeling heatmap, keys contains list of all words in title2
    keys = list(vec2.keys())
    #  if ith word in intersection(lis of words of title1 and list of words of title2): values(i)=count of that word in title2 else values(i)=0 
    values = [vec2[x] for x in vec2.keys()]
    
    # labels: len(labels) == len(keys), the values of labels depends on the model we are using
        # if model == 'bag of words': labels(i) = values(i)
        # if model == 'tfidf weighted bag of words':labels(i) = tfidf(keys(i))
        # if model == 'idf weighted bag of words':labels(i) = idf(keys(i))

    if model == 'bag_of_words':
        labels = values
    elif model == 'tfidf':
        labels = []
        for x in vec2.keys():
            # tfidf_title_vectorizer.vocabulary_ it contains all the words in the corpus
            # tfidf_title_features[doc_id, index_of_word_in_corpus] will give the tfidf value of word in given document (doc_id)
            if x in  tfidf_title_vectorizer.vocabulary_:
                labels.append(tfidf_title_features[doc_id, tfidf_title_vectorizer.vocabulary_[x]])
            else:
                labels.append(0)
    elif model == 'idf':
        labels = []
        for x in vec2.keys():
            # idf_title_vectorizer.vocabulary_ it contains all the words in the corpus
            # idf_title_features[doc_id, index_of_word_in_corpus] will give the idf value of word in given document (doc_id)
            if x in  idf_title_vectorizer.vocabulary_:
                labels.append(idf_title_features[doc_id, idf_title_vectorizer.vocabulary_[x]])
            else:
                labels.append(0)

    plot_heatmap(keys, values, labels, url, text)


# this function gets a list of wrods along with the frequency of each 
# word given "text"
def text_to_vector(text):
    word = re.compile(r'\w+')
    words = word.findall(text)
    # words stores list of all words in given string, you can try 'words = text.split()' this will also gives same result
    return Counter(words) # Counter counts the occurence of each word in list, it returns dict type object {word1:count}



def get_result(doc_id, content_a, content_b, url, model):
    text1 = content_a
    text2 = content_b
    
    # vector1 = dict{word11:#count, word12:#count, etc.}
    vector1 = text_to_vector(text1)

    # vector1 = dict{word21:#count, word22:#count, etc.}
    vector2 = text_to_vector(text2)

    plot_heatmap_image(doc_id, vector1, vector2, url, text2, model)

# %% [markdown]
# # Bag of Words (BoW) on product titles

# %%
from sklearn.feature_extraction.text import CountVectorizer
title_vectorizer = CountVectorizer()
title_features = title_vectorizer.fit_transform(data['title'])
title_features.shape

# %%
def bag_of_words_model(doc_id, num_results):
    
    pairwise_dist = pairwise_distances(title_features, title_features[doc_id])
    
    indices = np.argsort(pairwise_dist.flatten())[0:num_results]
    
    pdists = np.sort(pairwise_dist.flatten())[0:num_results]
    
    df_indices = list(data.index[indices])
    
    for i in range(0,len(indices)):
        # we will pass 1. doc_id, 2. title1, 3. title2, url, model
        get_result(indices[i],data['title'].loc[df_indices[0]], data['title'].loc[df_indices[i]], data['medium_image_url'].loc[df_indices[i]], 'bag_of_words')
        print('ASIN :',data['asin'].loc[df_indices[i]])
        print ('Brand:', data['brand'].loc[df_indices[i]])
        print ('Title:', data['title'].loc[df_indices[i]])
        print ('Euclidean similarity with the query image :', pdists[i])
        print('='*60)

        
        
bag_of_words_model(12566, 20)

# %%
   '''
    pairwise_dist = pairwise_distances(title_features, title_features[27])
    pairwise_dist
   
   '''

# %% [markdown]
# # TF-IDF based product similarity

# %%
tfidf_title_vectorizer = TfidfVectorizer(min_df = 0)
tfidf_title_features = tfidf_title_vectorizer.fit_transform(data['title'])

# %%
def tfidf_model(doc_id, num_results):
    
    pairwise_dist = pairwise_distances(tfidf_title_features, tfidf_title_features[doc_id])
    
    indices = np.argsort(pairwise_dist.flatten())[0:num_results]
    
    pdists = np.sort(pairwise_dist.flatten())[0:num_results]
    
    df_indices = list(data.index[indices])
    
    for i in range(0,len(indices)):
        # we will pass 1. doc_id, 2. title1, 3. title2, url, model
        get_result(indices[i], data['title'].loc[df_indices[0]], data['title'].loc[df_indices[i]], data['medium_image_url'].loc[df_indices[i]], 'tfidf')
        print('ASIN :',data['asin'].loc[df_indices[i]])
        print('BRAND :',data['brand'].loc[df_indices[i]])
        print ('Eucliden distance from the given image :', pdists[i])
        print('='*125)
    
tfidf_model(12566, 20)
